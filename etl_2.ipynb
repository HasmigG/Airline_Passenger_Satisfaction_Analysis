# %%
import csv
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Resources/airlines_reviews.csv')
df.head(2)
# Out:
#                                   Title              Name Review Date  \
# 0                    Flight was amazing  Alison Soetantyo  2024-03-01
# 1  seats on this aircraft are dreadful      Robert Watson  2024-02-21
#
#               Airline Verified  \
# 0  Singapore Airlines     True
# 1  Singapore Airlines     True
#
#                                              Reviews Type of Traveller  \
# 0    Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1    Booking an emergency exit seat still meant h...      Solo Leisure
#
#      Month Flown                 Route           Class  Seat Comfort  \
# 0  December 2023  Jakarta to Singapore  Business Class             4
# 1  February 2024   Phuket to Singapore   Economy Class             5
#
#    Staff Service  Food & Beverages  Inflight Entertainment  Value For Money  \
# 0              4                 4                       4                4
# 1              3                 4                       4                1
#
#    Overall Rating Recommended
# 0               9         yes
# 1               3          no

# %%
print(f'Rows and Columns: {df.shape}')
df.columns
# Out:
# Rows and Columns: (8100, 17)
# Index(['Title', 'Name', 'Review Date', 'Airline', 'Verified', 'Reviews',
#        'Type of Traveller', 'Month Flown', 'Route', 'Class', 'Seat Comfort',
#        'Staff Service', 'Food & Beverages', 'Inflight Entertainment',
#        'Value For Money', 'Overall Rating', 'Recommended'],
#       dtype='object')

# %%
ratings = list(df.iloc[:,16].values)

# %%
def Route_split (route):
    split_route = route.split()
    if len(route) > 1 and route[1][0].isupper():
        return route[0] + '' + route[1], route[2]
    else:
        return route[0], route[2]
df[['Origin', 'Destination']] = df['Route'].apply(Route_split)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7r/fhv8rs1j6j93m4kmfynxx5180000gn/T/ipykernel_20053/4167683306.py in ?()
#       3     if len(route) > 1 and route[1][0].isupper():
#       4         return route[0] + '' + route[1], route[2]
#       5     else:
#       6         return route[0], route[2]
# ----> 7 df[['Origin', 'Destination']] = df['Route'].apply(Route_split)
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4075
#    4076         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4077             self._setitem_frame(key, value)
#    4078         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4079             self._setitem_array(key, value)
#    4080         elif isinstance(value, DataFrame):
#    4081             self._set_item_frame_value(key, value)
#    4082         elif (
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4134                 value = DataFrame(value).values
#    4135                 return self._setitem_array(key, value)
#    4136
#    4137             else:
# -> 4138                 self._iset_not_inplace(key, value)
#
# ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4153                 return obj[i]
#    4154
#    4155         if self.columns.is_unique:
#    4156             if np.shape(value)[-1] != len(key):
# -> 4157                 raise ValueError("Columns must be same length as key")
#    4158
#    4159             for i, col in enumerate(key):
#    4160                 self[col] = igetitem(value, i)
#
# ValueError: Columns must be same length as key

# %%
df.iloc[17]
# Out:
# Title                                               one of the best flights
# Name                                                               E Darlon
# Review Date                                                      2024-01-25
# Airline                                                  Singapore Airlines
# Verified                                                               True
# Reviews                     Booked a wheelchair service from Milan to Ba...
# Type of Traveller                                              Solo Leisure
# Month Flown                                                    January 2024
# Route                                        Milan to Bangkok via Singapore
# Class                                                         Economy Class
# Seat Comfort                                                              4
# Staff Service                                                             5
# Food & Beverages                                                          5
# Inflight Entertainment                                                    5
# Value For Money                                                           5
# Overall Rating                                                           10
# Recommended                                                             yes
# Name: 17, dtype: object

# %%
with open('Resources/airlines_reviews.csv', 'r') as file:
    reader = csv.reader(file)
    # Skip the header row if it exists
    next(reader, None)

    # Iterate over the rows and extract the comments
    comments = [row[0] for row in reader]

    ratings = [float(row[16]) for row in reader]

polarities = []
subjectivities = []

# Analyze the sentiment of each comment
for comment in comments:
    blob = TextBlob(comment)
    polarity = blob.sentiment.polarity
    subjectivity = blob.sentiment.subjectivity
    polarities.append(polarity)
    subjectivities.append(subjectivity)
    
    print(f"Comment: {comment}")
    print(f"Polarity: {polarity}")
    print(f"Subjectivity: {subjectivity}")
    print()
# Out:
# Comment: Flight was amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: seats on this aircraft are dreadful
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: Food was plentiful and tasty
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: “how much food was available
# Polarity: 0.30000000000000004
# Subjectivity: 0.30000000000000004
#
# Comment: “service was consistently good”
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: “seat is absolutely dreadful”
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: Very ordinary service
# Polarity: -0.325
# Subjectivity: 0.65
#
# Comment: I like flying this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: left me deeply disappointed
# Polarity: -0.375
# Subjectivity: 0.375
#
# Comment: can’t fault a single aspect
# Polarity: -0.07142857142857142
# Subjectivity: 0.21428571428571427
#
# Comment: No complaints at all
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: “I was impressed”
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: “Superb service”
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: regional seat was really uncomfortable
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: “no problems whatsoever”
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: crew serving business disappeared
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: agent took out travel insurance on my behalf
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: one of the best flights
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: “received amazing support”
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: not fly with them in the future
# Polarity: -0.2
# Subjectivity: 0.5125
#
# Comment: Barely any room to move
# Polarity: 0.05
# Subjectivity: 0.1
#
# Comment: “outstanding service”
# Polarity: 0.5
# Subjectivity: 0.875
#
# Comment: brilliant experience
# Polarity: 0.9
# Subjectivity: 1.0
#
# Comment: best alongside Qatar Airways
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: allocated us three different seats
# Polarity: 0.0
# Subjectivity: 0.6
#
# Comment: Deficient reservation system
# Polarity: -0.4
# Subjectivity: 0.7
#
# Comment: swapping my itinerary to one day earlier
# Polarity: 0.0
# Subjectivity: 0.5
#
# Comment: “flight delayed almost 4 hours”
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I slept better than in economy
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: customer service is a nightmare
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: “No inflight entertainment at all”
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: easy, comfortable experience
# Polarity: 0.4166666666666667
# Subjectivity: 0.8166666666666667
#
# Comment: “Above and beyond”
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: delayed 24 hours in September 2023
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: “they have not followed through”
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: “not the Singapore Airlines I know!”
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Never again Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Food was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: An excellent experience
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: SQ has not provided any explanation
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Very poor service
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: great choices of movies
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: only offered an option of fish or vegetarian
# Polarity: 0.0
# Subjectivity: 1.0
#
# Comment: tell me that they cannot find my luggage
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: refused to compensate the costs
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: disastrous layover in Singapore
# Polarity: -0.7
# Subjectivity: 0.8
#
# Comment: It was a good flight
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: crew was really courteous and helpful
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: Cabin crew were very nice and helpful
# Polarity: 0.78
# Subjectivity: 1.0
#
# Comment: an extra $200 for a 10kg backpack
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: The meals are low quality
# Polarity: 0.0
# Subjectivity: 0.3
#
# Comment: charged me a cancellation fee of US$200
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I recommend this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Hats off to the crew
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flight was very pleasant
# Polarity: 0.9533333333333333
# Subjectivity: 1.0
#
# Comment: no better than Economy fare
# Polarity: -0.25
# Subjectivity: 0.5
#
# Comment: Do your own check in online
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: Helpful, polite and well presented!
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I found the seats a bit uncomfortable
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: consideration and rapid response
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a very good experience
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: a very pleasant journey
# Polarity: 0.9533333333333333
# Subjectivity: 1.0
#
# Comment: Unbelievable devotion to service!
# Polarity: -0.3125
# Subjectivity: 1.0
#
# Comment: always great new planes
# Polarity: 0.4681818181818182
# Subjectivity: 0.6022727272727273
#
# Comment: experience was second to none
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: premium price for economy quality
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: served a lovely dinner
# Polarity: 0.5
# Subjectivity: 0.75
#
# Comment: Exceptionally shine
# Polarity: 0.6666666666666666
# Subjectivity: 1.0
#
# Comment: professional and comfortable
# Polarity: 0.25
# Subjectivity: 0.45
#
# Comment: they’ve begun to nose-dive
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: offered 100 dollars full settlement
# Polarity: 0.35
# Subjectivity: 0.55
#
# Comment: Baggage handling was very poor
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: We had a wonderful crew
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: The service was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: outstanding customer service
# Polarity: 0.5
# Subjectivity: 0.875
#
# Comment: Overall not a bad flight
# Polarity: 0.17499999999999996
# Subjectivity: 0.3333333333333333
#
# Comment: way better than other airlines
# Polarity: 0.1875
# Subjectivity: 0.4375
#
# Comment: Great service and food
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: by far the worst customer service
# Polarity: -0.45
# Subjectivity: 1.0
#
# Comment: Service was excellent as expected
# Polarity: 0.45
# Subjectivity: 0.7
#
# Comment: not as good I was expecting
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: ask my wife to do it by herself
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was pleasantly surprised
# Polarity: 0.1
# Subjectivity: 0.9
#
# Comment: In-flight service was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: really nice for a sub 2-hour flight
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: In-flight service was quite nice
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: needed a GF Vegan meal
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: not professional behavior on the part of SA’s FAs
# Polarity: -0.05
# Subjectivity: 0.1
#
# Comment: Worst business class seats
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: They still have high standards
# Polarity: 0.16
# Subjectivity: 0.5399999999999999
#
# Comment: seats were hard and uncomfortable
# Polarity: -0.39583333333333337
# Subjectivity: 0.7708333333333333
#
# Comment: special praise for Air Stewardess
# Polarity: 0.35714285714285715
# Subjectivity: 0.5714285714285714
#
# Comment: another 6 weeks for the refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: rather disappointed
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: a very nice experience
# Polarity: 0.78
# Subjectivity: 1.0
#
# Comment: provided the very best
# Polarity: 1.0
# Subjectivity: 0.39
#
# Comment: The suite very comfortable
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: totally disappointing
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: my luggage was damaged
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Compensation should have been upgrade
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Very poor service
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: Service and crew were excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: Cabin staff didn't seem very happy
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: not recommend this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: wide ranging cost cutting exercise
# Polarity: -0.35
# Subjectivity: 0.65
#
# Comment: the service and staff was mediocre
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: helpful, courteous and polite
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: another great flight with SQ
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: cabin crew truly went above and beyond
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: 50 minutes for the priority baggage
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: late by up to 90 mins
# Polarity: -0.3
# Subjectivity: 0.6
#
# Comment: revitalise the quality of inflight meals
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a really great crew
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: refused to offer me any compensation
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: This airline is worth the money
# Polarity: 0.3
# Subjectivity: 0.1
#
# Comment: SQ are still up with the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: very good crew
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: The food was not good
# Polarity: -0.35
# Subjectivity: 0.6000000000000001
#
# Comment: We were disappointed
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: comfy seat, good service
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: did not offer toiletries pack
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: very friendly and attentive
# Polarity: 0.44375000000000003
# Subjectivity: 0.775
#
# Comment: Impeccable service
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment: no manned counters available for economy class
# Polarity: 0.4
# Subjectivity: 0.4
#
# Comment: usual pleasant experience at Changi
# Polarity: 0.24166666666666664
# Subjectivity: 0.6083333333333334
#
# Comment: I do not appreciate being treated like a fool
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I want to congratulate the crew
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Good food and great cabin crew
# Polarity: 0.75
# Subjectivity: 0.675
#
# Comment: there was no more beer onboard
# Polarity: -0.25
# Subjectivity: 0.5
#
# Comment: up to their usual high standards
# Polarity: -0.045
# Subjectivity: 0.39499999999999996
#
# Comment: very positive other than food
# Polarity: 0.08522727272727273
# Subjectivity: 0.5420454545454545
#
# Comment: Excellent plane. Great service
# Polarity: 0.9
# Subjectivity: 0.875
#
# Comment: boxes fixed under the seats
# Polarity: 0.1
# Subjectivity: 0.2
#
# Comment: The staff was very pleasant
# Polarity: 0.9533333333333333
# Subjectivity: 1.0
#
# Comment: their refund is not fair
# Polarity: -0.35
# Subjectivity: 0.9
#
# Comment: very attentive and informative
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: cabin crew was amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: A decent experience
# Polarity: 0.16666666666666666
# Subjectivity: 0.6666666666666666
#
# Comment: we were 4 minutes late
# Polarity: -0.3
# Subjectivity: 0.6
#
# Comment: cabin crew were amazingly good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: Hospitality was five-star
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment:  Singapore Airline is the best airline
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: miss pre-pandemic Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a very average experience
# Polarity: -0.195
# Subjectivity: 0.52
#
# Comment: crew really are the highlight
# Polarity: 0.2
# Subjectivity: 0.2
#
# Comment: best airline I have ever been on
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: the experience was delightful
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: A good seat, tasteless food
# Polarity: 0.04999999999999999
# Subjectivity: 0.75
#
# Comment: It was a 5/10 flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: My inflight food was very bad
# Polarity: -0.9099999999999998
# Subjectivity: 0.8666666666666667
#
# Comment: seats although adequate were so much smaller
# Polarity: 0.16666666666666666
# Subjectivity: 0.41666666666666663
#
# Comment: a good flight was spoiled by an awful start
# Polarity: -0.15000000000000002
# Subjectivity: 0.8
#
# Comment: Delayed baggage when I arrived
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seriously reconsider premium economy
# Polarity: -0.3333333333333333
# Subjectivity: 0.6666666666666666
#
# Comment: Would happily fly with them again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: offer me the Business Class entrée
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: hard-working cabin crew
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: lived up to high expectations
# Polarity: 0.16
# Subjectivity: 0.5399999999999999
#
# Comment: provides excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: maybe the best experience
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: seats were super uncomfortable
# Polarity: -0.08333333333333334
# Subjectivity: 0.8333333333333333
#
# Comment: the cabin crew were excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: pay SGD 1700 to rebook the flight change
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: chicken curry for breakfast?
# Polarity: -0.6
# Subjectivity: 0.95
#
# Comment: I have no words for the hospitality
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: denial that it even took place
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Last time SA for us
# Polarity: 0.0
# Subjectivity: 0.06666666666666667
#
# Comment: Overall a very good flight
# Polarity: 0.45499999999999996
# Subjectivity: 0.39000000000000007
#
# Comment: don't provide salt and pepper
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was not offered a drink
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: cancelling our paid seats
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: back with their reputation intact
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Still my favorite airline
# Polarity: 0.5
# Subjectivity: 1.0
#
# Comment: food was terrible
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: Very disappointed
# Polarity: -0.9750000000000001
# Subjectivity: 0.9750000000000001
#
# Comment: this is what a good flight should be
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: JFK check in a disaster
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: decline in service and product
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: A pleasant experience
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: can’t say enough for their warm hospitality
# Polarity: 0.3
# Subjectivity: 0.55
#
# Comment: stressful end to the trip
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: extremely dated and old aircrafts
# Polarity: -0.012499999999999997
# Subjectivity: 0.6
#
# Comment: attempting to locate my luggage
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: would always choose to fly with Singapore
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: I am not impressed
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: My meal was very poor
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: requested to provide a seat together
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: all special meals has been handed out
# Polarity: 0.35714285714285715
# Subjectivity: 0.5714285714285714
#
# Comment: said it was Lufthansa’s fault
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: an amazing experience
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: definitely fly with Singapore Airlines again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: meal was very poor in quantity and quality
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: outstanding service at the airport
# Polarity: 0.5
# Subjectivity: 0.875
#
# Comment: Very comfortable plane
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: crew was very friendly and interactive
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: lunch service took almost 3 hours
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: it was a pleasant flight
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: recommend the B737-800 Max business class
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: they lost my luggage
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: no more gift for kids
# Polarity: -0.25
# Subjectivity: 0.5
#
# Comment: a cheerful and engaged crew
# Polarity: 0.4
# Subjectivity: 1.0
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: food tray was near empty
# Polarity: 0.0
# Subjectivity: 0.45
#
# Comment: cannot find your seat again
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: airline has good inflight service
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: perceptions can be very different
# Polarity: 0.0
# Subjectivity: 0.78
#
# Comment: little to no choices for me
# Polarity: -0.1875
# Subjectivity: 0.5
#
# Comment: service and amenity-cuts
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: cancelled my flight for operational reasons
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: cabin crew some of the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Truly friendly staff
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: it was a far cry from the past
# Polarity: -0.075
# Subjectivity: 0.625
#
# Comment: the crew seemed to be overworked and de-motivated
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Thanks to ground staff
# Polarity: 0.2
# Subjectivity: 0.2
#
# Comment: Singapore Airlines is still the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: my reserved seat was not honored
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: worst food in business class
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: I had excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: the standard remains remarkable,
# Polarity: 0.375
# Subjectivity: 0.375
#
# Comment: flight was very disappointing
# Polarity: -0.78
# Subjectivity: 0.9099999999999999
#
# Comment: meals were one of the worst
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: The food was only just enough
# Polarity: 0.0
# Subjectivity: 0.75
#
# Comment: No wifi all flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: definitely fly Singapore Airlines again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: child was running up and down the aisle
# Polarity: -0.15555555555555559
# Subjectivity: 0.2888888888888889
#
# Comment: Lets hope the quality of food and wine improves to how it once was
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: definitely continue to fly with them
# Polarity: 0.4
# Subjectivity: 0.7
#
# Comment: Lots of room for improvement
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Significant lower services and amenities
# Polarity: 0.375
# Subjectivity: 0.875
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: requests were pending for both flights
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: A350 seats are thin and hard
# Polarity: -0.3458333333333333
# Subjectivity: 0.6958333333333333
#
# Comment: asked for a refund/compensation
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: service has been going down and prices going up
# Polarity: -0.15555555555555559
# Subjectivity: 0.2888888888888889
#
# Comment: the experience was amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: refuses to refund my ticket
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I feel the standards are dropping
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: waiting for check-in for over 2 hours
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Very average service
# Polarity: -0.195
# Subjectivity: 0.52
#
# Comment: service has been downgrade
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Singapore Airlines only allow 30 kgs total
# Polarity: 0.0
# Subjectivity: 0.875
#
# Comment: unreasonable pricing policy changes
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Service was all over the place
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Impossible to change my booking online
# Polarity: -0.6666666666666666
# Subjectivity: 1.0
#
# Comment: very kind, helpful and caring
# Polarity: 0.78
# Subjectivity: 1.0
#
# Comment: We totally enjoy the flight
# Polarity: 0.4
# Subjectivity: 0.5
#
# Comment: a very friendly service
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: too many business class seats
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: no inflight entertainment or even music
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Meal was excellent by any standard
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: happy with a Continental breakfast
# Polarity: 0.8
# Subjectivity: 1.0
#
# Comment: No salad or cheese
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: trying to get in touch with Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: all they would refund were the taxes
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seats are a step back in quality
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Only 1 meal was served on the flight
# Polarity: 0.0
# Subjectivity: 1.0
#
# Comment: the food was an utter disaster
# Polarity: 0.0
# Subjectivity: 1.0
#
# Comment: really disappointed with the meals
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: needs to treat it's customers with respect
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: kind to refund me fully
# Polarity: 0.6
# Subjectivity: 0.9
#
# Comment: flights themselves were rather unremarkable
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: It is still a great way to fly
# Polarity: 0.8
# Subjectivity: 0.825
#
# Comment: poor design of business class
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: Can't wait to fly Business Class again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: still a good and safe airline
# Polarity: 0.6
# Subjectivity: 0.55
#
# Comment: their website is too buggy
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: reduce both the level and quality of service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the change would cost 490 USD
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was disappointed with my flights
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: frustrating experience trying to book a flight
# Polarity: -0.4
# Subjectivity: 0.9
#
# Comment: the staff were outstanding
# Polarity: 0.5
# Subjectivity: 0.875
#
# Comment: staff on these flights were fantastic
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: like to get a refund for my ticket
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I don’t like being taken advantage of
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: they made us occupy all 3 seats
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Overall, I was pleased
# Polarity: 0.25
# Subjectivity: 0.5
#
# Comment: buy a new and very expensive ticket
# Polarity: -0.25681818181818183
# Subjectivity: 0.6822727272727273
#
# Comment: requested for a reinstatement of my ticket
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: wanted to thank Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: airline is ignoring requests
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: agreed to process a refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: enjoyed this midnight flight
# Polarity: 0.5
# Subjectivity: 0.7
#
# Comment: I enjoyed their Boeing 787
# Polarity: 0.5
# Subjectivity: 0.7
#
# Comment: the flight was very pleasant
# Polarity: 0.9533333333333333
# Subjectivity: 1.0
#
# Comment: I cancelled my flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: told again and again to wait
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: does not give you full refunds
# Polarity: 0.35
# Subjectivity: 0.55
#
# Comment: there was a fare difference
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: justify charging customers
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I recommend Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: just want a refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I never expected such behavior from SQ
# Polarity: 0.025
# Subjectivity: 0.45
#
# Comment: crew were friendly and efficient
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: A big thank you
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: cabin staff were fantastic
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: an excellent experience
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: tried to call many times
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: cannot reach a ticketing agent
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: have not allowed refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: cabin crew is nice
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: in-flight meal taste great
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: a pleasant flight
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: food and crew were amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: gave me a hard time with baggage
# Polarity: -0.2916666666666667
# Subjectivity: 0.5416666666666666
#
# Comment: Crew was friendly
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: not comfortable as I expected
# Polarity: -0.15000000000000002
# Subjectivity: 0.6000000000000001
#
# Comment: I am USD 100 out of pocket
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: no dedicated crew in premium economy
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: it was totally worth it!
# Polarity: 0.375
# Subjectivity: 0.1
#
# Comment: felt very disappointed
# Polarity: -0.9750000000000001
# Subjectivity: 0.9750000000000001
#
# Comment: air crew were friendly and professional
# Polarity: 0.2375
# Subjectivity: 0.3
#
# Comment: given a very generic meal
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Overall a great flightW
# Polarity: 0.4
# Subjectivity: 0.375
#
# Comment: refused give me refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: my seat had a broken table
# Polarity: -0.4
# Subjectivity: 0.4
#
# Comment: superior customer service
# Polarity: 0.7
# Subjectivity: 0.9
#
# Comment: Poor food quality
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: still remain my top choice
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: the biggest disappointment
# Polarity: -0.6
# Subjectivity: 0.4
#
# Comment: the legroom is pretty decent
# Polarity: 0.20833333333333331
# Subjectivity: 0.8333333333333333
#
# Comment: lack in common courtesy
# Polarity: -0.3
# Subjectivity: 0.5
#
# Comment: has dramatically improved
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: food was not really tasty
# Polarity: -0.1
# Subjectivity: 0.2
#
# Comment: my ticket was marked as flown
# Polarity: 0.1
# Subjectivity: 0.6
#
# Comment: ran out of certain dishes
# Polarity: 0.21428571428571427
# Subjectivity: 0.5714285714285714
#
# Comment: the best flight ever
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Service was good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: the gate was closed
# Polarity: -0.1
# Subjectivity: 0.1
#
# Comment: proceeded to first class check in
# Polarity: 0.25
# Subjectivity: 0.3333333333333333
#
# Comment: not overly friendly service
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: impressed with the cabin crew
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: experience left a bad taste
# Polarity: -0.3499999999999999
# Subjectivity: 0.3333333333333333
#
# Comment: very friendly and accommodating
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: another excellent flight
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: Amazing staff and food
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: a great flight with SQ
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: control consumption of alcohol
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: very difficult to sleep
# Polarity: -0.65
# Subjectivity: 1.0
#
# Comment: meals were unappetising
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Staff were very friendly
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: a really good flight
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: seats were comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: still an enjoyable flight
# Polarity: 0.5
# Subjectivity: 0.6
#
# Comment: Great service
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: my suitcase was damaged
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: shout out a special Thanks
# Polarity: 0.2785714285714286
# Subjectivity: 0.3857142857142857
#
# Comment: received budget airline service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: delays with boarding
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: has disappointed us
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: lack of crew dedicated to premium economy is an issue
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: recent flight with SQ was near flawless
# Polarity: 0.3666666666666667
# Subjectivity: 0.5499999999999999
#
# Comment: don’t hand out amenity kits
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I am still happy with SQ
# Polarity: 0.8
# Subjectivity: 1.0
#
# Comment: Excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: service was generally good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: most comfortable experienced
# Polarity: 0.5666666666666668
# Subjectivity: 0.7333333333333334
#
# Comment: crew provided excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: had a nice surprise
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: service is impeccable
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment: Very poor communication
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: amazing experience for us
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: helpful staff
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: my experience was far from being positive
# Polarity: 0.16363636363636364
# Subjectivity: 0.7727272727272727
#
# Comment: quick, friendly and precise
# Polarity: 0.36944444444444446
# Subjectivity: 0.6
#
# Comment: my seat not functioning
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: quite disappointing
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: The food on this flight was awful
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: disappointed with the food
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: maintained its excellent standard
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: decor bland and functional
# Polarity: -0.16666666666666666
# Subjectivity: 0.8333333333333334
#
# Comment: premium economy is a good choice
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: with low cost carrier Scoot
# Polarity: 0.0
# Subjectivity: 0.3
#
# Comment: appreciate the staff service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: met my expectations fully
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: needs competently met and exceeded
# Polarity: 0.5
# Subjectivity: 0.6666666666666666
#
# Comment: barely offer water to people
# Polarity: 0.05
# Subjectivity: 0.1
#
# Comment: Great service in business class
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: Overall, a good flight
# Polarity: 0.35
# Subjectivity: 0.30000000000000004
#
# Comment: crew were not efficient
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a pleasant experience
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: not recommend this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: economy service in premium economy
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: boarding pass in two compartments
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: not provide the vegetarian food
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: experience was fabulous
# Polarity: 0.4
# Subjectivity: 1.0
#
# Comment: I expected much more
# Polarity: 0.2
# Subjectivity: 0.45
#
# Comment: service is nothing to shout out about
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: getting more disappointing over time
# Polarity: -0.04999999999999999
# Subjectivity: 0.6
#
# Comment: Service was inconsistent
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Very poor service in business class
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: service has really gone downhill
# Polarity: 0.2
# Subjectivity: 0.2
#
# Comment: Service still lives up to its name
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Service is the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: do not seem to be committed to premium economy
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was disappointed with the seat
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: I will fly Singapore Airlines again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: very impressive flight
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: each time is a little worse
# Polarity: -0.29375
# Subjectivity: 0.55
#
# Comment: crew very friendly
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: my worst Economy flight ever
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: deterioration in the level of service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: they gave us seafood instead
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Cabin crew were amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: was disappointed again
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: found it very unprofessional
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: Extremely disappointed
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: a very overpriced disappointing experience
# Polarity: -0.19999999999999998
# Subjectivity: 0.5
#
# Comment: expected it to be much better
# Polarity: 0.2
# Subjectivity: 0.45
#
# Comment: provide an excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: service was almost perfect
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: No personalised service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Everything went smoothly
# Polarity: 0.4
# Subjectivity: 0.5
#
# Comment: cabin crew was rushing
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: The damage is already done
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: bitter resentment on my part
# Polarity: -0.1
# Subjectivity: 0.5
#
# Comment: Excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: love the aircraft
# Polarity: 0.5
# Subjectivity: 0.6
#
# Comment: Warm hospitality
# Polarity: 0.6
# Subjectivity: 0.6
#
# Comment: service offered was perfect
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: What an experience
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: best airline I’ve flown
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Wonderful experience
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: Service is excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: a great experience
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: service was top-notch
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: a comfortable flight
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: I was very impressed
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: unable to select the seat
# Polarity: -0.5
# Subjectivity: 0.5
#
# Comment: efficiency and reliability
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: service still excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: a disappointing flight
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: A350 was really enjoyable
# Polarity: 0.5
# Subjectivity: 0.6
#
# Comment: the crew were meticulous
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: We travelled without meals
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: there is nothing premium about the service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: will return to AirAsia for future flights
# Polarity: 0.0
# Subjectivity: 0.125
#
# Comment: definitely fly Singapore again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: quality at its best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: flight is perpetually delayed
# Polarity: -0.05
# Subjectivity: 0.2
#
# Comment: crew seemed to be quite inattentive
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: not even close to Qatar Airways
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Overall great experience
# Polarity: 0.4
# Subjectivity: 0.375
#
# Comment: usual high standard of SIA is there
# Polarity: -0.03
# Subjectivity: 0.2633333333333333
#
# Comment: processes of serving special meals
# Polarity: 0.35714285714285715
# Subjectivity: 0.5714285714285714
#
# Comment: absolutely appalled by the service
# Polarity: -0.8
# Subjectivity: 1.0
#
# Comment: most uncomfortable seats
# Polarity: 0.0
# Subjectivity: 0.75
#
# Comment: Simply the best!
# Polarity: 0.5
# Subjectivity: 0.32857142857142857
#
# Comment: amazing cabin crew service
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: Food was quite good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: overall impression was pretty good
# Polarity: 0.31666666666666665
# Subjectivity: 0.5333333333333333
#
# Comment: A380 looks a little shabby
# Polarity: -0.1875
# Subjectivity: 0.5
#
# Comment: the worst most arrogant crew
# Polarity: -0.25
# Subjectivity: 0.75
#
# Comment: One of the best inflight services
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: The seat was in a word, horrible
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: What a disappointing flight
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: standards seem to be declining
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: big thank you for everyone
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: very pleasant and enjoyable
# Polarity: 0.7266666666666666
# Subjectivity: 0.8
#
# Comment: located within 50cm of toilets
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Fantastic service
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: poor value for money
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: I am utterly disappointed
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: Highly recommend Singapore
# Polarity: 0.16
# Subjectivity: 0.5399999999999999
#
# Comment: she was refused entry
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: \Would definitely recommend
# Polarity: 0.0
# Subjectivity: 0.5
#
# Comment: Cabin service was exceptional as usual
# Polarity: 0.20833333333333331
# Subjectivity: 0.625
#
# Comment: service and food was great
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: good for economy class
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: Such a disappointment
# Polarity: -0.3
# Subjectivity: 0.45
#
# Comment: economy class is good value
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: All in all poor value
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: Crew are a mixed bag
# Polarity: 0.0
# Subjectivity: 0.25
#
# Comment: was the worst flight
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: whole staff was great
# Polarity: 0.5
# Subjectivity: 0.575
#
# Comment: a five star experience
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: standard has dropped drastically
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: best feature was the legroom
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Not good enough
# Polarity: -0.175
# Subjectivity: 0.55
#
# Comment: not at the level they used to be
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: reputation from the past
# Polarity: -0.25
# Subjectivity: 0.25
#
# Comment: Horrible first time experience
# Polarity: -0.375
# Subjectivity: 0.6666666666666666
#
# Comment: the worst seats ever
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: recommend Singapore Airlines
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Seats are comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: Very good service
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: I would not recommend
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Everything was as expected
# Polarity: -0.1
# Subjectivity: 0.4
#
# Comment: Seat was very uncomfortable
# Polarity: -0.65
# Subjectivity: 1.0
#
# Comment: really felt disappointment
# Polarity: -0.19999999999999998
# Subjectivity: 0.30000000000000004
#
# Comment: Crew were very polite
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: Shockingly rude staff
# Polarity: -0.3
# Subjectivity: 0.6
#
# Comment: missing the flight
# Polarity: -0.2
# Subjectivity: 0.05
#
# Comment: perfect experience
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: I would recommend
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: aircraft that was so cold
# Polarity: -0.6
# Subjectivity: 1.0
#
# Comment: disappointed and annoyed
# Polarity: -0.575
# Subjectivity: 0.775
#
# Comment: Seat was comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: a pleasant experience
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: superb service we received
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: my baggage not on the plane
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the crew were attentive
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: excellent and attentive service
# Polarity: 0.7
# Subjectivity: 0.95
#
# Comment: Excellent cabin staff
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: not very well designed
# Polarity: -0.1
# Subjectivity: 0.3
#
# Comment: very bad cabin experience
# Polarity: -0.9099999999999998
# Subjectivity: 0.8666666666666667
#
# Comment: It's amazing how good you can sleep
# Polarity: 0.65
# Subjectivity: 0.75
#
# Comment: A great flight
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: poor special meal
# Polarity: -0.021428571428571436
# Subjectivity: 0.5857142857142856
#
# Comment: my experience was mixed
# Polarity: 0.0
# Subjectivity: 0.25
#
# Comment: not rate my journey a pleasant one
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: by far the best
# Polarity: 0.55
# Subjectivity: 0.65
#
# Comment: seats are comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: a fantastic airline
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: plane now seems a bit tired
# Polarity: -0.4
# Subjectivity: 0.7
#
# Comment: plastic wasted horrifying
# Polarity: -0.55
# Subjectivity: 0.5
#
# Comment: couldn't fault the service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a very high standard throughout
# Polarity: 0.10400000000000001
# Subjectivity: 0.351
#
# Comment: you lost a loyal flyer
# Polarity: 0.3333333333333333
# Subjectivity: 0.8333333333333334
#
# Comment: a pleasant experience
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: performed poor sloppy service
# Polarity: -0.4083333333333333
# Subjectivity: 0.675
#
# Comment: had to sit rows apart
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seats very well-designed
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment:  one of the best out there
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: a good economy experience
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: a very comfortable flight
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: food was satisfying
# Polarity: 0.5
# Subjectivity: 1.0
#
# Comment: my seat could not lie flat
# Polarity: -0.025
# Subjectivity: 0.125
#
# Comment: great cabin crew and great food
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: were very impressed
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: seat width is narrower
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: attentive and helpful
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: so nice and friendly
# Polarity: 0.4875
# Subjectivity: 0.75
#
# Comment: Would definitely recommend
# Polarity: 0.0
# Subjectivity: 0.5
#
# Comment: No pillows available
# Polarity: 0.4
# Subjectivity: 0.4
#
# Comment: journey was just about okay
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: best in its category
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: cabin crew were very polite
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: best flight we ever had
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Service was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: seats are so comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: hard time selecting seats
# Polarity: -0.2916666666666667
# Subjectivity: 0.5416666666666666
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: big improvement in service
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: ended up with an economy meal
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: The seats are smaller
# Polarity: 0.0
# Subjectivity: 0.5
#
# Comment: different airline via Moscow
# Polarity: 0.0
# Subjectivity: 0.6
#
# Comment: experience onboard quite standard
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: wanted 2200$ for upgrade
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Flight attendants were elegantly efficient
# Polarity: 0.5
# Subjectivity: 1.0
#
# Comment: seats are not very comfortable
# Polarity: -0.15384615384615385
# Subjectivity: 0.6153846153846154
#
# Comment: crew were proactive with drinks
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Food average and service slow
# Polarity: -0.22500000000000003
# Subjectivity: 0.39999999999999997
#
# Comment: experience was less convincing
# Polarity: 0.16666666666666669
# Subjectivity: 0.5333333333333333
#
# Comment: really a disappointment
# Polarity: -0.6
# Subjectivity: 0.4
#
# Comment: Excellent service all the way
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: Disappointed this time
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: polite as usual
# Polarity: -0.25
# Subjectivity: 0.25
#
# Comment: problem was my Mileage Plus
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: disappointed this time
# Polarity: -0.75
# Subjectivity: 0.75
#
# Comment: outstanding in their service
# Polarity: 0.5
# Subjectivity: 0.875
#
# Comment: No kids menu provided
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: an impeccable flight
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment:  below subpar performance
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the seats are very comfortable
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: overall flight was okay
# Polarity: 0.25
# Subjectivity: 0.25
#
# Comment: never use Singapore Air anymore
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was pleasantly surprised
# Polarity: 0.1
# Subjectivity: 0.9
#
# Comment: service in Sydney unprofessional
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: fantastic service
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: best business class experience
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: service was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: wine which I don't like
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: atmosphere was cold
# Polarity: -0.6
# Subjectivity: 1.0
#
# Comment: premium economy is ordinary
# Polarity: -0.25
# Subjectivity: 0.5
#
# Comment: a great cabin crew
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: missed my connecting flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: offered far better privacy
# Polarity: 0.3
# Subjectivity: 0.75
#
# Comment: best in the world
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: 10 out of 10 for the flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Cabin staff great
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: cabin crew were superb
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: my best economy flight
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: really comfortable seats
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: A fantastic experience
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: they lacked international food
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: exceptional service by the crew
# Polarity: 0.6666666666666666
# Subjectivity: 1.0
#
# Comment: service was faultless
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: still a pleasant journey
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: A fantastic airline
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: never had a worse experience
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: seats were decently spaced out
# Polarity: 0.16666666666666666
# Subjectivity: 0.6666666666666666
#
# Comment: a very charming service
# Polarity: 0.9099999999999999
# Subjectivity: 1.0
#
# Comment: Cabin staff were good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: Service was fantastic
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: don't take responsibility
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: back to UK was very good
# Polarity: 0.45499999999999996
# Subjectivity: 0.39000000000000007
#
# Comment: No refund is forthcoming
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Economy never felt so good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: amateurish attitude
# Polarity: -0.4
# Subjectivity: 0.8
#
# Comment: great flight with Singapore Airlines
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: The meal was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: have to pay for the change
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: delayed the refund
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: service was pleasant
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: very comfortable flight
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: a very comfortable flight
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: excellent staff and service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: cabin crew was amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: such hard seats
# Polarity: -0.14583333333333334
# Subjectivity: 0.5208333333333333
#
# Comment: Singapore Airlines customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I would fly them again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: Excellent service onboard
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: seats have seen better days
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: seems to have improved
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment:  crew extremely polite and helpful
# Polarity: -0.125
# Subjectivity: 1.0
#
# Comment: unpleasant boarding experience
# Polarity: -0.6499999999999999
# Subjectivity: 0.95
#
# Comment: best airline in the world
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: my favorite carrier
#
# Polarity: 0.5
# Subjectivity: 1.0
#
# Comment: a perfect option so far
# Polarity: 0.55
# Subjectivity: 1.0
#
# Comment: crew were very engaged
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: amazing short flight
# Polarity: 0.30000000000000004
# Subjectivity: 0.6
#
# Comment: aircraft was perfect
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: it was comfortable enough
# Polarity: 0.2
# Subjectivity: 0.65
#
# Comment: Crew were varying
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Meals were mediocre quality
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: has wider seat-TV screen
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: inflight meal was really premium
# Polarity: 0.2
# Subjectivity: 0.2
#
# Comment: A great experience
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: disappointing experience
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: happy with the service and care
# Polarity: 0.8
# Subjectivity: 1.0
#
# Comment: did an excellent job
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: totally forgettable
# Polarity: -0.5
# Subjectivity: 0.5
#
# Comment: very friendly flight attendant
# Polarity: 0.34375
# Subjectivity: 0.525
#
# Comment: impressed with the journey
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: a very good experience
# Polarity: 0.9099999999999999
# ...
# Subjectivity: 1.0
#
# Comment: cabin staff very friendly
# Polarity: 0.48750000000000004
# Subjectivity: 0.65
#
# Comment: great flight with EVA
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: they are my preferred choice
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flight itself was lovely
# Polarity: 0.5
# Subjectivity: 0.75
#
# Comment: the airline of my choice
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: I was very impressed
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: better than Singapore and Lufthansa
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: prices were good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: business class product is great
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: super professional and attentive crew
# Polarity: 0.2777777777777778
# Subjectivity: 0.5555555555555555
#
# Comment: planes were modern and clean
# Polarity: 0.2833333333333333
# Subjectivity: 0.5
#
# Comment: I was expecting more
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: I was expecting more
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: appreciate their excellent service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: my best flight so far
# Polarity: 0.55
# Subjectivity: 0.65
#
# Comment: they had switched my seat
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Inflight service is great
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: professional and kind service
# Polarity: 0.35
# Subjectivity: 0.5
#
# Comment: food & beverage were spot on
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: friendly and professional crew
# Polarity: 0.2375
# Subjectivity: 0.3
#
# Comment: our best flight
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: a pleasant flight experience
# Polarity: 0.7333333333333333
# Subjectivity: 0.9666666666666667
#
# Comment: were left disappointed
# Polarity: -0.375
# Subjectivity: 0.375
#
# Comment: cabin staff were quite superb
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: a great flight experience
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: service was with a smile
# Polarity: 0.3
# Subjectivity: 0.1
#
# Comment: fantastic service again
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: more legroom in economy class
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: “excellent service provided by crew”
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: “it was a solid experience”
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: Really great experience
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: “Absolutely horrible customer service”
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: she was so helpful and courteous
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: No courtesy to passengers
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: above average legroom
# Polarity: -0.075
# Subjectivity: 0.25
#
# Comment: service by the flight attendants was ok
# Polarity: 0.5
# Subjectivity: 0.5
#
# Comment: service is very shabby
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: I’d fly them again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: Five stars service and friendliness
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flight attendants super polite
# Polarity: 0.3333333333333333
# Subjectivity: 0.6666666666666666
#
# Comment: they switched up on us at the last minute
# Polarity: 0.0
# Subjectivity: 0.06666666666666667
#
# Comment: We were very impressed
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: Great accommodation for economy
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: crew so friendly and nice
# Polarity: 0.4875
# Subjectivity: 0.75
#
# Comment: I enjoy flying with this airline
# Polarity: 0.4
# Subjectivity: 0.5
#
# Comment: crew were efficient and friendly
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: extra inch or so of leg room they have
# Polarity: 0.0
# Subjectivity: 0.1
#
# Comment: Prestige class? I don’t think so
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Food and beverages are delicious
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: rely on the consistent service
# Polarity: 0.25
# Subjectivity: 0.25
#
# Comment: happy enough with this flight
# Polarity: 0.4
# Subjectivity: 0.75
#
# Comment: an impressive airline
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: seated separately from my pregnant partner
# Polarity: 0.3333333333333333
# Subjectivity: 0.5
#
# Comment: Check in and boarding very organized
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: Very poor customer service
# Polarity: -0.52
# Subjectivity: 0.78
#
# Comment: Service was consistent!
# Polarity: 0.3125
# Subjectivity: 0.25
#
# Comment: impressed with the spacious cabin
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: never had an airline weigh my carry-ons
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Poor reducing customer service2
# Polarity: -0.4
# Subjectivity: 0.6
#
# Comment: great for a 1 hour flight
# Polarity: 0.8
# Subjectivity: 0.75
#
# Comment: a nice flight overall
# Polarity: 0.3
# Subjectivity: 0.5
#
# Comment: never by Korean Air again
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flight was one of the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: will fly Korean Air whenever possible
# Polarity: 0.4
# Subjectivity: 0.95
#
# Comment: 300 USD for cancelling
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: On-time and friendly crew
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: certain tickets cannot book seats in advance
# Polarity: 0.21428571428571427
# Subjectivity: 0.5714285714285714
#
# Comment:  Service on plane was nice
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: The food was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: The service was amazing
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: my mother was refused boarding
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Korean Air customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: professional and attentive
# Polarity: 0.25
# Subjectivity: 0.5
#
# Comment: lost my wallet before boarding
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: recommend this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: really enjoyed it
# Polarity: 0.5
# Subjectivity: 0.7
#
# Comment: made me dislike this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: They insulted me in Korean
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flying Korean air next time
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: very pleased with Korean Air
# Polarity: 0.65
# Subjectivity: 1.0
#
# Comment: This airline was disappointing
# Polarity: -0.6
# Subjectivity: 0.7
#
# Comment: appreciate all their effort
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seats comfortable
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: The crew were unfriendly
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: nothing very impressive
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: overall poor customer service
# Polarity: -0.2
# Subjectivity: 0.3
#
# Comment: experience is bad
# Polarity: -0.6999999999999998
# Subjectivity: 0.6666666666666666
#
# Comment: experience onboard Korean was underwhelming
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Tomato Soup for breakfast?
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: thank her for her amazing help
# Polarity: 0.6000000000000001
# Subjectivity: 0.9
#
# Comment: food was very good quality
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: IFE screens were good
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: professional and courteous
# Polarity: 0.35
# Subjectivity: 0.55
#
# Comment: would recommend this airline as always
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seats are somewhat out of date
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: it's so hard to book with them
# Polarity: -0.2916666666666667
# Subjectivity: 0.5416666666666666
#
# Comment: very bothering experience
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: wouldn’t recommend it
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Cabin staff attentive
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: attentive but not so friendly
# Polarity: 0.3875
# Subjectivity: 0.7
#
# Comment: Other than the heat it’s fabulous
# Polarity: 0.1375
# Subjectivity: 0.6875
#
# Comment: Horrendous problem solving
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the most excellent crew
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment: recommend the airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: highly allergic to paint
# Polarity: 0.16
# Subjectivity: 0.5399999999999999
#
# Comment: Worst international airline
# Polarity: -0.5
# Subjectivity: 0.5
#
# Comment: Next trip with Korean air
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: highly recommend Korean Air
# Polarity: 0.16
# Subjectivity: 0.5399999999999999
#
# Comment: the coldest airport staff
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: refused to even talk to me
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: hardware was very dated
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: staff is efficient
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Very sterile service
# Polarity: 0.2
# Subjectivity: 0.3
#
# Comment: Had a nice flight
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: The leg room was spacious
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: team were really kind
# Polarity: 0.6
# Subjectivity: 0.9
#
# Comment: make my two kids sit separately
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the bad customer service
# Polarity: -0.6999999999999998
# Subjectivity: 0.6666666666666666
#
# Comment: worst flight I have experienced
# Polarity: -0.09999999999999998
# Subjectivity: 0.95
#
# Comment: a good experience
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: travel with Korean Air again
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: business class product is sub-par
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: worst customer service
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: I am very disappointed
# Polarity: -0.9750000000000001
# Subjectivity: 0.9750000000000001
#
# Comment: like the foods on board
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: seats with unbelievable leg space
# Polarity: -0.25
# Subjectivity: 1.0
#
# Comment: utter lack of caring
# Polarity: 0.0
# Subjectivity: 1.0
#
# Comment: friendly and personable
# Polarity: 0.375
# Subjectivity: 0.5
#
# Comment: nickel and dime culture
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Transit was a breeze
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: absence of footrest in economy
# Polarity: -0.0125
# Subjectivity: 0.0
#
# Comment: would fly Korean Air again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: I would fly with KE again
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: not use this airline again
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: the food was below par
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: never recommend flying Korean Air
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: aircraft was new and comfy
# Polarity: 0.13636363636363635
# Subjectivity: 0.45454545454545453
#
# Comment: polite, helpful, and nice
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: It was a nice experience
# Polarity: 0.6
# Subjectivity: 1.0
#
# Comment: a pathetic experience
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: perfect cabin crew
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: FA's polite and attentive
#
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: Service was inexcusable
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: never travel with Korean Air again
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: a very good experience
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: unpleasant one to travel with
# Polarity: -0.6499999999999999
# Subjectivity: 0.95
#
# Comment: I had a positive experience
# Polarity: 0.22727272727272727
# Subjectivity: 0.5454545454545454
#
# Comment: food was of good standard
# Polarity: 0.35
# Subjectivity: 0.30000000000000004
#
# Comment: Worst flight experience ever
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: recommend to avoid this airline
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: failed to inform passengers
# Polarity: -0.5
# Subjectivity: 0.3
#
# Comment: they are very robotic
# Polarity: -0.13
# Subjectivity: 0.26
#
# Comment: all of their four legs was delayed
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: flight attendants were terrible
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: level of personalized service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: not fly them again by choice.
# Polarity: -0.4
# Subjectivity: 0.9
#
# Comment: good value for money
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: Korean Air customer review
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: comfortable seat with ample leg space
# Polarity: 0.4
# Subjectivity: 0.8
#
# Comment: the worst that I have ever flown
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: commend the flight attendants
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Seats still extremely spacious with leg room
# Polarity: -0.125
# Subjectivity: 1.0
#
# Comment: totally unacceptable service
# Polarity: 0.0
# Subjectivity: 0.75
#
# Comment: Reasonable price too
# Polarity: 0.2
# Subjectivity: 0.6
#
# Comment: pleasant flight overall
# Polarity: 0.36666666666666664
# Subjectivity: 0.48333333333333334
#
# Comment: terrible experience with Korean Air
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: Seat wise it was comfortable
# Polarity: 0.55
# Subjectivity: 0.8500000000000001
#
# Comment: service was good as always
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: the meaning of customer service
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: crew were very attentive
# Polarity: 0.52
# Subjectivity: 1.0
#
# Comment: flight crew was excellent
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: best four flights I have ever been on
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: provided best possible service
# Polarity: 0.5
# Subjectivity: 0.65
#
# Comment: The legroom is remarkable
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment: Excellent service provided
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: never take Korean Air anymore
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: leg room was the best
# Polarity: 1.0
# Subjectivity: 0.3
#
# Comment: Excellent service both ways
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: cheaper than premium economy
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: my flight was wonderful
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: good and very comfortable
# Polarity: 0.61
# Subjectivity: 0.8
#
# Comment: the staff were very respectful and courteous
# Polarity: 0.625
# Subjectivity: 0.955
#
# Comment: I wish never made the purchase
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: appallingly slow with zero sense of urgency
# Polarity: -0.30000000000000004
# Subjectivity: 0.39999999999999997
#
# Comment: terrible customer service
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: impressed by the legroom
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: exceptionally good value
# Polarity: 0.7
# Subjectivity: 0.6000000000000001
#
# Comment: very polite charming flight attendants
# Polarity: 0.44999999999999996
# Subjectivity: 0.65
#
# Comment: everyone was extremely courteous and professional
# Polarity: 0.35
# Subjectivity: 0.55
#
# Comment: service was exceptional
# Polarity: 0.6666666666666666
# Subjectivity: 1.0
#
# Comment: would not hesitate to fly again with them
# Polarity: 0.8
# Subjectivity: 0.9
#
# Comment: food mediocre on both legs
# Polarity: -0.5
# Subjectivity: 1.0
#
# Comment: my last flight with them
# Polarity: 0.0
# Subjectivity: 0.06666666666666667
#
# Comment: crew attentive and helpful
# Polarity: 0.4
# Subjectivity: 0.9
#
# Comment: standard flight with no frills
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: arrive in Europe fresh and rested
# Polarity: 0.3
# Subjectivity: 0.5
#
# Comment: staff were really helpful
# Polarity: 0.2
# Subjectivity: 0.2
#
# Comment: counter service was horrible
# Polarity: -1.0
# Subjectivity: 1.0
#
# Comment: very good service
# Polarity: 0.9099999999999999
# Subjectivity: 0.7800000000000001
#
# Comment: the worst Asian airline
# Polarity: -0.5
# Subjectivity: 0.5
#
# Comment: I felt like a valued customer
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: had a positive experience
# Polarity: 0.22727272727272727
# Subjectivity: 0.5454545454545454
#
# Comment: excellent customer service
# Polarity: 1.0
# Subjectivity: 1.0
#
# Comment: helpful ground service staff
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: service was impeccable
# Polarity: 0.75
# Subjectivity: 0.75
#
# Comment: no crew speaks French
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: service good, comfort the missing element
# Polarity: 0.24999999999999997
# Subjectivity: 0.32500000000000007
#
# Comment: I was satisfied with the performance
# Polarity: 0.5
# Subjectivity: 1.0
#
# Comment: aircraft was immaculate
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: an uneventful flight
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: Korean Air always impresses
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: didn’t offer anything
# Polarity: 0.0
# Subjectivity: 0.0
#
# Comment: appreciated the service onboard
# Polarity: 0.2
# Subjectivity: 0.1
#
# Comment: genuinely friendly staff
# Polarity: 0.375
# Subjectivity: 0.5

# %%
ratings
# Out:
# ['yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  ...]

# %%
plt.figure(figsize=(8, 6))
scatter = plt.scatter(polarities, subjectivities, c=ratings, cmap='viridis', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.title('Polarity vs. Subjectivity')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4483, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4482 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4483     colors = mcolors.to_rgba_array(c)
#    4484 except (TypeError, ValueError) as err:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/colors.py:503, in to_rgba_array(c, alpha)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/colors.py:503, in <listcomp>(.0)
#     502     else:
# --> 503         rgba = np.array([to_rgba(cc) for cc in c])
#     504 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/colors.py:302, in to_rgba(c, alpha)
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/colors.py:384, in _to_rgba_no_colorcycle(c, alpha)
#     383         return c, c, c, alpha if alpha is not None else 1.
# --> 384     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     385 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'yes'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 2
#       1 plt.figure(figsize=(8, 6))
# ----> 2 scatter = plt.scatter(polarities, subjectivities, c=ratings, cmap='viridis', alpha=0.5)
#       3 plt.xlabel('Polarity')
#       4 plt.ylabel('Subjectivity')
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4670, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4667 if edgecolors is None:
#    4668     orig_edgecolor = kwargs.get('edgecolor', None)
#    4669 c, colors, edgecolors = \
# -> 4670     self._parse_scatter_color_args(
#    4671         c, edgecolors, kwargs, x.size,
#    4672         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4674 if plotnonfinite and colors is None:
#    4675     c = np.ma.masked_invalid(c)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4492, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4489             raise invalid_shape_exception(c.size, xsize) from err
#    4490         # Both the mapping *and* the RGBA conversion failed: pretty
#    4491         # severe failure => one may appreciate a verbose feedback.
# -> 4492         raise ValueError(
#    4493             f"'c' argument must be a color, a sequence of colors, "
#    4494             f"or a sequence of numbers, not {c!r}") from err
#    4495 else:
#    4496     if len(colors) not in (0, 1, xsize):
#    4497         # NB: remember that a single color is also acceptable.
#    4498         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not ['yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes',  ...

# %%
plt.figure(figsize=(8, 6))
scatter = plt.scatter(polarities, subjectivities, c=ratings, cmap='viridis', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.title('Polarity vs. Subjectivity')
plt.show()
# Out:
# /var/folders/7r/fhv8rs1j6j93m4kmfynxx5180000gn/T/ipykernel_8247/2299643750.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = plt.scatter(polarities, subjectivities, c=ratings, cmap='viridis', alpha=0.5)

# %%
df['Name'].nunique()
# Out:
# 6583

# %%
df['Title']
# Out:
# 0                         Flight was amazing
# 1       seats on this aircraft are dreadful
# 2               Food was plentiful and tasty
# 3               “how much food was available
# 4            “service was consistently good”
#                         ...
# 8095                    an uneventful flight
# 8096             Korean Air always impresses
# 8097                   didn’t offer anything
# 8098         appreciated the service onboard
# 8099                genuinely friendly staff
# Name: Title, Length: 8100, dtype: object

# %%
df['Title'].value_counts()
# Out:
# Title
# Turkish Airlines customer review    11
# Qatar Airways customer review       11
# worst customer service               9
# a pleasant experience                9
# seats were comfortable               8
#                                     ..
# very comfortable experience          1
# not impressed by the performance     1
# ANA is simply the best               1
# bad communication                    1
# genuinely friendly staff             1
# Name: count, Length: 7614, dtype: int64

# %%
df['Route'].value_counts()
# Out:
# Route
# Bangkok to Hong Kong                  24
# London to Singapore                   23
# Istanbul to London                    20
# Bangkok to Singapore                  20
# Hong Kong to Singapore                19
#                                       ..
# Amsterdam to Cebu via Dubai            1
# Ho Chi Minh to Frankfurt via Dubai     1
# Sydney to Moscow via Dubai             1
# Brisbane to Madrid via Dubai           1
# ICN to YYZ                             1
# Name: count, Length: 5566, dtype: int64

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Turkish Airlines          1685
# Qatar Airways             1624
# Emirates                  1350
# Singapore Airlines         972
# Air France                 798
# Cathay Pacific Airways     744
# EVA Air                    281
# All Nippon Airways         258
# Japan Airlines             201
# Korean Air                 187
# Name: count, dtype: int64

# %%
# keep routes & split into Origin & Destination, find coord for the locations
# Target "Recommended"
# maybe user can provide the following and 
# Type of Traveller', 'Route', 'Class', 'Seat Comfort',
# 'Staff Service', 'Food & Beverages', 'Inflight Entertainment',
# 'Value For Money
